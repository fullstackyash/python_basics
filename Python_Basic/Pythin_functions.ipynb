# %% [markdown]
# # Python Function

# %%
def myfucntion():
    print("Hello World")

# %%
myfucntion()
# Out:
# Hello World

# %%
def addition(num1, num2):
    print(f'the addition of {num1} and {num2} is {num1+num2}')

# %%
addition(5, 10)
# Out:
# the addition of 5 and 10 is 15

# %% [markdown]
# # Function with Variable length arguments

# %%
def addition_variable(*nums):
    add = 0
    for num in nums:
        add += num
    print(f'the addition of {nums} is {add}')

# %%
addition_variable(10,20,30,40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 addition(10,20,30,40)
#
# TypeError: addition() takes 2 positional arguments but 4 were given
