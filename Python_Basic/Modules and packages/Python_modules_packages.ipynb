# %% [markdown]
# # Modules and packages

# %% [markdown]
# ### If you want to use someone else code or use code from another file we make use of modules and packages. A module is a file containing Python definitions and statements. A package is a way of structuring Python’s module namespace by using “dotted module names”. For example, the module name A.B designates a submodule named B in a package named A. We can use the import statement to import modules and packages in our code. For example, we can import the os module to work with the operating system. We cam import the os module using the following code:
# import os

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %% [markdown]
# ### Module - A module in python is a file that contains Python code. It can define functions, classes, and variables. A module can also include runnable code. Modules are a way to organize code and reuse it across different programs. You can create your own modules or use built-in modules that come with Python.

# %% [markdown]
# ### Numpy - A powerful library for numerical computing in Python. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays efficiently. Numpy is widely used in data science, machine learning, and scientific computing.

# %% [markdown]
# ### Pandas - A powerful library for data manipulation and analysis. It provides data structures like DataFrame and Series, which are essential for handling structured data.

# %%
### Types of imports
# 1. Importing the entire module
import math
print(math.sqrt(16))
# 2. Importing specific functions or classes from a module
from math import sqrt
print(sqrt(16))
# 3. Importing a module with an alias
import math as m
print(m.sqrt(16))
# 4. Importing specific functions or classes from a module with an alias
from math import sqrt as square_root
print(square_root(16))  
# 5. Importing all functions and classes from a module (not recommended)
from math import *
print(sqrt(16))
# Out:
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0

# %%
import numpy as np
print(np.sqrt(16))
# Out:
# 4.0

# %%
# !pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 3.9 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.8 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 3.6 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.9 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [seaborn]m7/9 [matplotlib]
# ...

# %% [markdown]
# ### To create our own module, __init__.py file is required in the folder. This file can be empty or can contain code. The presence of this file indicates that the folder is a package and can be imported as a module. For example, if we have a folder named my_package with an __init__.py file, this file can be empty as well, but should be there inside a folder
