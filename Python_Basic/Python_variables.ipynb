# %% [markdown]
# # Variables in Python

# %% [markdown]
# ## Variables in Python are elements that can store some data or value in it.
# ## Data stored in a variable can vary or can be changed.

# %%
age=23
Name="Yash"
Height=5.8

# %%
age
# Out:
# 23

# %%
Name
# Out:
# 'Yash'

# %%
Height
# Out:
# 5.8

# %% [markdown]
# ## Print() --> function is used to print any value we will pass inside it

# %%
print("Name is:",Name)
# Out:
# Name is: Yash

# %%
print("Age is:",age)
# Out:
# Age is: 23

# %% [markdown]
# # Comments

# %% [markdown]
# ## Comment is a statement in a program that we don't want interpreter to executed

# %% [markdown]
# ## Interpreter --> Executes code line by line

# %% [markdown]
# ## Compiler --> Executes code completely

# %%
# THIS IS A COMMENT

# %%
 This is not a comment
# Out:
#   Cell In[15], line 1
#     This is not a comment
#                   ^
# SyntaxError: invalid syntax

# %%
'''
This
is
a
multi-line
comment
'''
# Out:
# '\nThis\nis\na\nmulti-line\ncomment\n'

# %% [markdown]
# # Variable Naming Conventions
#
# ## Variables names should be descriptive

# %%
Age = 24

# %% [markdown]
# # They must start with a letter or underscore

# %%
_name = "Yash"

# %%
1name = "Yash"
# Out:
#   Cell In[1], line 1
#     1name = "Yash"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## Variable Type

# %%
print(type(Age))
# Out:
# <class 'int'>

# %% [markdown]
# ## Typecasting

# %%
Age = str(Age)
print(type(Age))
# Out:
# <class 'str'>

# %%
print(type(_name))
# Out:
# <class 'str'>

# %% [markdown]
# ## Every typecasting is not possible i.e from string to integer

# %%
_name = int(_name) # This will raise an error because "Yash" cannot be converted to an integer.
print(type(_name))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 _name = int(_name)
#       2 print(type(_name))
#
# ValueError: invalid literal for int() with base 10: 'Yash'

# %% [markdown]
# ## Input() Function

# %% [markdown]
# ## Input function can take value from the user and store it to a variable

# %%
Name=input("Enter your name: ")

# %%
print(Name)
# Out:
# Yash Chopra

# %%
age=input("Enter your age: ")

# %%
print(age)
# Out:
# 2d
